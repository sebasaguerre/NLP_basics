# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import re

os.makedirs('./results', exist_ok=True)

with open('./brown_100.txt', 'r') as file_:
    corpus = file_.read()

def write_freqs(list_: list, filename: str) -> None:
    with open(f'./results/{filename}.txt', 'w') as file_:
        file_.write('\n'.join([' '.join(x[0]) + ' | ' + str(x[1]) for x in list_]))

# %% [markdown]
# ## N-Gram Language Modeling
# In the second assignment, you will implement an **n-gram language model** that processes input text to generate, analyze, and calculate the probabilities of sequences of `n` words (n-grams). This model will tokenize text, create n-grams, and compute their frequencies and probabilities, returning the most frequent n-grams in the text.
#
# 1. **Tokenization**: Convert the input text into a list of words (tokens).
# 2. **N-gram Generation**: Create sequences of `n` tokens from the text, treating each sentence independently with the inclusion of start (`<s>`) and end (`</s>`) markers.
# 3. **Frequency Counting**: Count how many times each n-gram appears in the text.
# 4. **Probability Calculation**: Compute the probabilities of each n-gram based on its frequency and add alpha smoothing to improve generalization of items.
# 5. **Most Frequent N-grams**: Return the most frequent n-grams along with their probabilities, helping to identify common patterns in the text.

# %%
from collections import Counter, defaultdict # You may import more from collections if needed

class NGramModel:
    def __init__(self, text, n, alpha=0.0):
        """
        Initialize the NGramModel with text and the value of n.
        """
        self.text = text
        self.n = n
        self.alpha = alpha  # Alpha value for additive smoothing
        self.ngrams = {}
        self.frequencies = {}
        self.probabilities = {}
        self.vocab = set()

    def tokenize(self) -> None:
        """
        Tokenize the text into words. 
        Fill in the code to split the text into a list of words.
        """
        contractions = ["n't", "'s", "'re", "'ve", "'ll", "'d", "'m", "'t"]
        new_tokens = []
        #clean tokens
        initial_tokens = self.text.split(" ")
        tokens = [token.lower() for token in initial_tokens] #make all tokens lower
        tokens = [token.strip() for token in tokens] #strip extra whitespcae
        #handles punctuations before and after string
        for token in tokens:
            matched_p = re.match(rf"^(\W*)([\w']+)(\W*)$",token)
            if matched_p:
                if matched_p.group(1):
                    new_tokens.append(matched_p.group(1))
                if matched_p.group(2):
                    new_tokens.append(matched_p.group(2))
                if matched_p.group(3):
                    new_tokens.append(matched_p.group(3))
                continue
            else:
                new_tokens.append(token)
        tokens=new_tokens
        new_tokens = []

        # handle contractions
        for token in tokens:
            cont_bool =False
            for contraction in contractions:
                matched_c = re.match(rf"^(\w+){contraction}$",token)
                if matched_c:
                    new_tokens.append(matched_c.group(1))
                    new_tokens.append(contraction)
                    cont_bool =True
                    break
            if cont_bool ==False:
                new_tokens.append(token)
        tokens = new_tokens
        self.vocab = set(tokens)
        self.tokens = tokens 
        return tokens

    def generate_ngrams(self, tokens: list) -> dict:
        """
        Generate n-grams from the list of tokens.
        Fill in the code to create n-grams.
        Make sure to treat each sentence independently, include the <s> and </s> tokens.
        """
        # total number of n_grams possible given list of tokens 
        num_ngrams = len(tokens) - self.n + 1

        for idx, token in enumerate(tokens[:num_ngrams]):
            
            ngram = ["<s>"] # init ngram
            # generate n-gram starting with current token 
            for t in tokens[idx: idx + self.n]:
                ngram.append(t)

            # add generated ngrams 
            self.ngrams.setdefault(token, []).append(" ".join(ngram + ["</s>"]))

        return self.ngrams

    def count_frequencies(self) -> None:
        """
        Count the frequencies of each n-gram.
        Fill in the code to count n-gram occurrences.
        """
        self.n_gram_freq = defaultdict(int)

        for ngram_list in self.ngrams.values():
            for ngram_str in ngram_list:
                self.n_gram_freq[ngram_str] += 1

    def calculate_probabilities(self) -> None:
        """
        Calculate probabilities of each n-gram based on its frequency. Add alpha smoothing separately.
        """

        self.probabilities = {}
        V = len(self.vocab)  # Vocabulary size for smoothing

        # Compute prefix frequencies
        prefix_freqs = defaultdict(int)
        for ngram_str in self.n_gram_freq:
            tokens = ngram_str.split()
            prefix = " ".join(tokens[:-1])
            prefix_freqs[prefix] += self.n_gram_freq[ngram_str]

        # Compute probabilities with smoothing
        for ngram_str in self.n_gram_freq:
            tokens = ngram_str.split()
            prefix = " ".join(tokens[:-1])
            count = self.n_gram_freq[ngram_str]
            prefix_count = prefix_freqs[prefix]
            smoothed_prob = (count + self.alpha) / (prefix_count + self.alpha * V)
            self.probabilities[ngram_str] = smoothed_prob

        return self.probabilities

    def most_frequent_ngrams(self, top_n: int = 10) -> list:
        """
        Return the most frequent n-grams and their probabilities.
        """
        
        # Sort n-grams by frequency in descending order
        sorted_grams = sorted(self.n_gram_freq.items(), key=lambda x: x[1], reverse=True)
        return sorted_grams[:top_n]

# Testing the model with an example
text = "This is a simple example to demonstrate how n-grams work in this assignment." #Faster than running the full corpus
n = 2  # You can change this to 1, 2, or 3 for uni, bi, or trigrams
model = NGramModel(text, n)

tokens = model.tokenize()
ngrams = model.generate_ngrams(tokens)
model.count_frequencies()
model.calculate_probabilities()
#to remove the stop sequence
print(ngrams)
# Out:
# {'this': ['<s> this is </s>', '<s> this assignment </s>'], 'is': ['<s> is a </s>'], 'a': ['<s> a simple </s>'], 'simple': ['<s> simple example </s>'], 'example': ['<s> example to </s>'], 'to': ['<s> to demonstrate </s>'], 'demonstrate': ['<s> demonstrate how </s>'], 'how': ['<s> how n-grams </s>'], 'n-grams': ['<s> n-grams work </s>'], 'work': ['<s> work in </s>'], 'in': ['<s> in this </s>'], 'assignment': ['<s> assignment . </s>']}

# %% [markdown]
# ### Unigrams
#
# In this section, we apply the `NGramModel` to our corpus. The model can be configured to generate unigrams, bigrams, or trigrams by adjusting the value of `n`. After tokenizing the text and generating the n-grams, the model counts the occurrences of each n-gram and calculates their probabilities. The most frequent n-grams are then written to an output file.
#
# By adjusting the n-gram size, we can analyze different levels of word dependencies in the text, providing insights into common word sequences and patterns.
#
# The code below will generate unigrams when the NGramModel is implemented correctly

# %%
n = 1  # You can change this to 1, 2, or 3 for uni, bi, or trigrams
model = NGramModel(corpus, n)

tokens = model.tokenize()
ngrams = model.generate_ngrams(tokens)
model.count_frequencies()
model.calculate_probabilities()

write_freqs(model.most_frequent_ngrams(10), 'unigrams')

# %% [markdown]
# ### Bigrams
# Bigrams allow us to explore word pairs and their relationships, providing insight into common word combinations and phrase structures within the corpus.
# The code below will generate bigrams when the NGramModel is implemented correctly.

# %%
n = 2  # You can change this to 1, 2, or 3 for uni, bi, or trigrams
model1 = NGramModel(corpus, n)

tokens = model.tokenize()
ngrams = model.generate_ngrams(tokens)
model1.count_frequencies()
model1.calculate_probabilities()

write_freqs(model1.most_frequent_ngrams(10), 'bigrams')

# %% [markdown]
# ### Trigrams
# Trigrams capture three-word sequences, providing a deeper understanding of longer word dependencies and commonly occurring phrases within the text.
# The code below will generate trigrams when the NGramModel is implemented correctly

# %%
n = 3  # You can change this to 1, 2, or 3 for uni, bi, or trigrams
model = NGramModel(corpus, n)

tokens = model.tokenize()
ngrams = model.generate_ngrams(tokens)
model.count_frequencies()
model.calculate_probabilities()

write_freqs(model.most_frequent_ngrams(10), 'trigrams')

# %% [markdown]
# ### Smoothing
# Below, we generate **bigrams** with **smoothing** applied by setting `n = 2` and including a smoothing parameter `alpha = 1.0`. Smoothing is useful in language models to handle unseen n-grams by assigning a small probability to them. The model tokenizes the text, generates bigrams, counts their frequencies, and calculates smoothed probabilities. The most frequent bigrams are then written to an output file.

# %%
n = 2  # You can change this to 1, 2, or 3 for uni, bi, or trigrams
model2 = NGramModel(corpus, n, alpha=1.0)

tokens = model2.tokenize()
ngrams = model2.generate_ngrams(tokens)
model2.count_frequencies()
model2.calculate_probabilities()
write_freqs(model2.most_frequent_ngrams(10), 'bigrams_smoothed')

# %%
smoothed_probs = model2.calculate_probabilities()
unsmoothed_probs = model1.calculate_probabilities()

common_bigrams = set(smoothed_probs.keys()).union(set(unsmoothed_probs.keys()))

for bigram in sorted(common_bigrams):
    smoothed = smoothed_probs.get(bigram, 0)
    unsmoothed = unsmoothed_probs.get(bigram, 0)
    print(f"{bigram}: Smoothed={smoothed:.6f}, Unsmoothed={unsmoothed:.6f}")
# Out:
# <s> $ 10 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> $ 100 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> $ 3 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> $ 30 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> $ 4 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> $ 50 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ' ' </s>: Smoothed=0.041617, Unsmoothed=0.000000
# <s> ' , </s>: Smoothed=0.009828, Unsmoothed=0.000000
# <s> ' . </s>: Smoothed=0.019465, Unsmoothed=0.000000
# <s> ' act </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ' and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ' as </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ' for </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ' in </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ' of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ' on </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ' pension </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ' that </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ' this </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ' to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ' vote </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's `` </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's action </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's age </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's attorney </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's automobile </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's campaign </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's congressmen </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's court </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's election </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's handling </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's most </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's new </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's occupation </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's office </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's present </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's race </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's recent </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's registration </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's resignation </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 's wards </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ( 1 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ( 2 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ( the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ) </ </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> ) passed </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , 1913 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , `` </s>: Smoothed=0.006165, Unsmoothed=0.000000
# <s> , a </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> , according </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , ala </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , among </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , and </s>: Smoothed=0.007389, Unsmoothed=0.000000
# <s> , anonymous </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , armed </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , as </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , both </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , but </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> , caldwell </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , calmest </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , colquitt </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , davis </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , elected </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , four </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , george </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , grady </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , guardians </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , hot </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , however </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> , in </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> , it </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> , medical </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , miller </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , mrs </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , one </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , or </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , pearl </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , pelham </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , provided </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , reportedly </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , resigned </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , said </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> , shot </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , since </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , something </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , state </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> , stood </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , texas </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , that </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , the </s>: Smoothed=0.020656, Unsmoothed=0.000000
# <s> , there </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> , too </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , was </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , which </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> , who </s>: Smoothed=0.006165, Unsmoothed=0.000000
# <s> , will </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , william </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> , with </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> -- a </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> -- after </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> -- and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> -- committee </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> -- where </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . , </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> . . </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> . 1 </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> . 13 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . 2 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . 8 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . </ </s>: Smoothed=0.100446, Unsmoothed=0.000000
# <s> . aj </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . b </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . bowden </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . callan </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . cheshire </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . d </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . dorsey </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . garland </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . gov </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . hartsfield </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . j </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . john </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . m </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . mac </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . marvin </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . pelham </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> . price </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> . vandiver </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 1 ) </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 1 . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 1 </ </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 1 the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 1,119 votes </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 10 per </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 100 million </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 13 primary </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 13th year </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 18 , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 1913 . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 1923 . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 1937 . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 1958 with </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 1961 session </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 1962 governor </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 2 ) </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 2 , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 2 </ </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 29-5 . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 3 million </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 30 million </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 4 million </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 402 . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 50 million </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 637 e </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 71 . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 74 and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 8 in </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> 87-31 . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> : ( </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> : 1 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> < s </s>: Smoothed=0.111356, Unsmoothed=0.000000
# <s> </ s </s>: Smoothed=0.111356, Unsmoothed=0.000000
# <s> >  </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > ( </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > -- </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> > < </s>: Smoothed=0.110375, Unsmoothed=0.000000
# <s> > `` </s>: Smoothed=0.011043, Unsmoothed=0.000000
# <s> > a </s>: Smoothed=0.006165, Unsmoothed=0.000000
# <s> > as </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > ask </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > attorneys </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > austin </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > barber </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > before </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > but </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > caldwell </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > colquitt </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > construction </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > davis </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > despite </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > during </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > five </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > four </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > fulton </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > georgia </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > gov </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > hartsfield </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > he </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> > henry </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > his </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> > however </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > i </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > implementation </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > in </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > it </s>: Smoothed=0.008610, Unsmoothed=0.000000
# <s> > many </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > mayor </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > meanwhile </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > merger </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > nevertheless </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > on </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > ordinary </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> > pelham </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> > regarding </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > rep </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > robert </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > sam </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > schley </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > sheriff </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > state </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > the </s>: Smoothed=0.033573, Unsmoothed=0.000000
# <s> > they </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > vandiver </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> > wards </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> > when </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> > while </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` a </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> `` abandoned </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` are </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> `` attorney </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` being </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` considering </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` coolest </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` deserves </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` endorse </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` everything </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` failure </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` give </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` has </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> `` in </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` irregularities </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` is </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` no </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` only </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` provide </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` quickie </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` take </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` that </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` there </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> `` these </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> `` this </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> `` to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` we </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> `` work </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a $ </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a battle </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a bit </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> a campaign </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a candidate </s>: Smoothed=0.006165, Unsmoothed=0.000000
# <s> a constitutional </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a daughter </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a disproportionate </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a dispute </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a doctor </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a drop </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a fair </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a first </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a friendly </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a gun </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a highway </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a legislator </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a long </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a manner </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a meeting </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a new </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a number </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a permit </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a pistol </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a plan </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a policeman </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a portion </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a primary </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a privilege </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a proportionate </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a relative </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a resolution </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> a result </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a revolving </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> a school </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a similar </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a son </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a state </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> a study </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a swipe </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a system </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a top </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a unanimous </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a veteran </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> a vote </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> a year </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> abandoned property </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> about the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> accepted practices </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> according to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> achieve greater </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> act , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> act `` </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> act seemed </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> action . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> action of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> action would </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> actions should </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> adamant protests </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> added that </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> additional deputies </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> additional rural </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> adjournment . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> adjournment monday </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> adjustments should </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> administration ' </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> administration and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> administrators and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> after a </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> after he </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> after mayor </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> afternoon , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> against the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> age as </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> agreed upon </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> agriculture teacher </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> aid to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> airport , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> airport be </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> aj . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ala . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> all the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> allen jr </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> allotted to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> allow legislators </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> allowances . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> allowed to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> alpharetta prison </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> also commented </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> also is </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> also recommended </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> alternative courses </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ambiguous ' </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> amendment to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> amicable property </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> among them </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> an amicable </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> an assistant </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> an interim </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> an investigation </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> an orderly </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> and `` </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and a </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and administrators </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and alpharetta </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and an </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and bush </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> and chairman </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and compensation </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and contracts </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and elected </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and election </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and equitable </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and expended </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and follow </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and fulton </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and head </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and his </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and improving </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and in </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and its </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and often </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and operation </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and place </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and promised </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and re-set </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and reduce </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and revised </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and thanks </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and the </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> and then </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and there </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and urban </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and veiled </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and we </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and weekend </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and wife </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> and williams </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> announced that </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> anonymous calls </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> anonymous midnight </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> anonymous telephone </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> any irregularities </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> apparently intends </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> apparently made </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> appointed and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> appointment of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> appraisers , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> approval of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> approve a </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> approved earlier </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> approved will </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> are getting </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> are outmoded </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> are paid </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> are some </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> are well </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> areas to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> armed with </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> as 71 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> as 74 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> as `` </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> as a </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> as his </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> as man </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> as of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> as opelika </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> as state </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> as the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> as they </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> aside the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ask jail </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ask the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> asked him </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> asked whether </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> asking the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> assistance program </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> assistant more </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> association and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> at 637 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> at church </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> at the </s>: Smoothed=0.008610, Unsmoothed=0.000000
# <s> at which </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> atlanta ' </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> atlanta 's </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> atlanta , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> atlanta and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> atlanta bar </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> atlanta police </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> attended . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> attorney ' </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> attorney . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> attorneys for </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> audience . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> audience was </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> aug . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> austin , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> authorities . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> authority a </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> authority bonds </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> automobile title </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> available funds </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> awarding of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> b . </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> back federal </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> back to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ballot , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> bankers . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> bar association </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> barber , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> barber of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> barber tossed </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> battle in </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be allowed </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be combined </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be directed </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be effected </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be employed </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> be formally </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be given </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be held </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be irregularities </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be issued </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be made </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be operated </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be periodic </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be received </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be repealed </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be sought </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be succeeded </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> be taken </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> be the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> became a </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> become a </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> been agreed </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> been an </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> been charged </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> been consulted </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> been expected </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> been mayor </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> been under </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> before adjournment </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> before making </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> begin and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> being at </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> being done </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> being offered </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> being ready </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> believes `` </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> bellwood and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> berry jr </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> best interest </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> birth as </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> bit of </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> blue ridge </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> board . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> board of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> body 's </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> bond issue </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> bond money </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> bonds . </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> bonds </ </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> bonds for </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> bonds proposed </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> bonds would </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> both candidates </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> both chambers </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> both governments </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> bowden was </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> brief interlude </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> brought enthusiastic </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> burden ' </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> bush , </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> bush got </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> but he </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> but it </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> but the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> by a </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> by at </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> by controversy </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> by fulton </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> by ivan </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> by mayor-nominate </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> by rob </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> by tax </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> by the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> by then </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> byrd 's </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> byrd . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> caldwell 's </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> caldwell , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> caldwell is </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> callan , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> calls . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> calls and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> calls soon </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> calmest election </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> campaign , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> campaign . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> campaign coordinator </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> campaign leading </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> campaign starts </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> can be </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> candidate , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> candidate for </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> candidate in </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> candidates , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> candidates on </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> career goes </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> carey williams </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> carry a </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> cent of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> certain thursday </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> chairman , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> chairman james </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> chairman of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> chambers as </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> charge jan </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> charge of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> charged by </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> charged mental </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> cheshire of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> child welfare </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> church . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> citizens committee </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> citizens feared </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> city ' </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> city `` </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> city council </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> city employes </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> city executive </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> city of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> city officials </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> city personnel </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> city purchasing </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> clerical personnel </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> colquitt </ </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> colquitt policeman </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> combined to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> commented on </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> commerce is </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> commissioner 's </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> committee , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> committee . </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> committee approval </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> compensation . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> concessionaires for </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> conducted . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> congress does </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> congressional delegation </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> congressmen specifically </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> considering the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> consistently opposed </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> constitution , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> constitutional amendment </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> construction bonds </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> construction work </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> consulted yet </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> continue to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> contracts let </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> controversy , </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> coolest , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> coolest election </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> coordinator for </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> cost of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> costs and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> council in </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> counties ' </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> counties in </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> county ' </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> county , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> county democratic </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> county general </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> county grand </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> county has </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> county jail </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> county legislator </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> county must </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> county purchasing </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> county rep </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> county school </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> county should </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> county unit </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> couple has </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> couple was </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> courses must </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> court 's </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> court `` </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> court friday </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> court judge </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> court which </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> courts for </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> criticisms ' </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> crowd was </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> cruelty . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> d . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> daniel 's </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> date so </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> daughter , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> davis , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> davis and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> davis received </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> day increase </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> days after </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> death march </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> defeated felix </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> delegation in </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> democratic executive </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> department 's </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> department , </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> department . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> department `` </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> department apparently </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> department is </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> department public </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> department source </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> departments of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> departments which </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> deputies </ </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> deputies be </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> deserves the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> despite the </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> details were </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> determine what </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> did find </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> did n't </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> did not </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> directed to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> director , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> disable this </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> disproportionate burden </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> dispute with </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> dissents . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> distribute these </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> distribution of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> divorce from </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> do this </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> doctor , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> does provide </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> done on </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> dorsey added </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> drop of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> during the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> durwood pye </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> duty at </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> e . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> each county </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> earlier in </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> education , </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> education should </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> effect the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> effected ' </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> effective date </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> efficiency and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> elaborate , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> elected , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> elected servants </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> elected texas </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> election , </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> election . </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> election ballot </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> election campaign </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> election i </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> election laws </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> election produced </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> election to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> election was </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> eliminate political </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> emphasizing that </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> employed at </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> employed for </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> employes . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> enabling funds </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> enabling legislation </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> encouragement to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> end of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> endorse increased </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> enter a </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> entering a </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> enthusiasm was </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> enthusiastic responses </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> equitable ' </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> establishment of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> event congress </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> ever saw </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> every time </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> everything went </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> evidence ' </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> exception of </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> executive committee </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> expected for </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> expected to </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> expended ' </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> expense allowances </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> experienced clerical </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> expires jan </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> extern be </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> face is </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> fact and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> failure to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> fair and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> farms , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> feared that </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> featured speaker </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> federal aid </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> federal funds </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> federal support </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> feel that </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> fees and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> felix bush </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> felix tabb </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> filed suit </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> find that </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> fire for </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> first $ </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> first be </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> first priority </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> first race </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> fit to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> five per </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> follow generally </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> follow shortly </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> for a </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> for byrd </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> for child </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> for city </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> for divorce </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> for future </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> for governor </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> for home </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> for its </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> for lt </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> for more </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> for night </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> for public </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> for reelection </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> for repair </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> for rural </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> for some </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> for the </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> force it </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> formally read </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> former county </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> foster homes </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> found the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> four additional </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> four days </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> friday , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> friday . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> friday an </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> friday in </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> friendly test </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> from his </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> from the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> from undue </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> from unmeritorious </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> fully worked </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> fulton county </s>: Smoothed=0.008610, Unsmoothed=0.000000
# <s> fulton health </s>: Smoothed=0.002475, Unsmoothed=0.000000
# ...
# <s> the praise </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the prices </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the pricing </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the privilege </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the purpose </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the race </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the recommendations </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the republicans </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> the resolution </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> the rural </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the sales </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the senate </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> the sept </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the september-october </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the session </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the sheriff </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the signatures </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the size </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the state </s>: Smoothed=0.008610, Unsmoothed=0.000000
# <s> the traditional </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the validity </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the voters </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the warning </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the welfare </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> the widespread </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> them ' </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> them the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> then gov </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> then the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> there `` </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> there also </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> there should </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> there to </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> there was </s>: Smoothed=0.006165, Unsmoothed=0.000000
# <s> there were </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> there would </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> these actions </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> these available </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> these funds </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> these laws </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> these two </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> they have </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> they realize </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> they work </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> this city </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> this county </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> this increase </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> this is </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> this money </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> this problem </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> this program </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> this was </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> this will </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> threats of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> three years </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> through 87-31 </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> through the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> thursday despite </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> time . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> time a </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> title law </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to $ </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to `` </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> to achieve </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to allow </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to anonymous </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to approve </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to back </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to be </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to become </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to both </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to carry </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to city </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to death </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to determine </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to distribute </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to do </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to education </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to enter </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> to face </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to first </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to have </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to his </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to insure </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to investigate </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to issue </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> to make </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> to obtain </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to offer </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to pass </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to place </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> to protect </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to remedy </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to republicans </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to rescind </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> to rural </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to see </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to set </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to take </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to teacher </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to test </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to the </s>: Smoothed=0.006165, Unsmoothed=0.000000
# <s> to vote </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to wait </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> to work </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> together as </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> told the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> tom williams </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> too , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> took a </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> took place </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> top official </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> topics , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> tossed into </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> toward adjournment </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> tower will </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> traditional visit </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> traveled highways </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> trouble ' </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> tuesday night </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> tuesday to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> two alternative </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> two offices </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> two previous </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> unanimous vote </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> under fire </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> under the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> under which </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> undue costs </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> unit system </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> unmeritorious criticisms </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> up for </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> up its </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> upon . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> urban areas </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> urged that </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> validity of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> vandiver has </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> vandiver is </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> vandiver likely </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> vandiver opened </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> veiled threats </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> very near </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> veteran agriculture </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> veteran jackson </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> violence . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> visit to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> vote of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> vote on </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> vote to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> voted no </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> voted through </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> voters . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> voters and </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> voters in </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> voters last </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> votes in </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> voting itself </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> voting precincts </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> w . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> wait one </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> wanted to </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> wards from </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> wards protected </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> warned that </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> warning , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was a </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was also </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was asked </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was conducted </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was just </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was learned </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was listed </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was marked </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was married </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was n't </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was no </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was not </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was picking </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was received </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was research </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was subjected </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was warned </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> was won </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> washington who </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> we did </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> we feel </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> wednesday . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> weekend duty </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> welfare department </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> welfare departments </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> welfare services </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> well operated </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> went real </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> were no </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> were not </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> what adjustments </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> when the </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> where some </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> whether it </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> whether notice </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> whether the </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> which barber </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> which had </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> which has </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> which inure </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> which it </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> which new </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> which newly </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> which receives </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> which says </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> which the </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> which was </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> while emphasizing </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> who attended </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> who became </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> who defeated </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> who has </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> who is </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> who would </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> widespread interest </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> wife 's </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> wife , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> wife for </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> will ask </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> will be </s>: Smoothed=0.006165, Unsmoothed=0.000000
# <s> will begin </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> will continue </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> will eliminate </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> will follow </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> will go </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> will mention </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> will offer </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> will permit </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> will wind </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> william b </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> william berry </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> williams , </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> williams got </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> williams hartsfield </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> williams said </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> wind up </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> with a </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> with city </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> with exception </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> with the </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> won by </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> word of </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> work . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> work for </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> work on </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> work toward </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> work with </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> worked out </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> worth of </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> would be </s>: Smoothed=0.004938, Unsmoothed=0.000000
# <s> would force </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> would have </s>: Smoothed=0.003708, Unsmoothed=0.000000
# <s> would like </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> would not </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> would seek </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> year . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> year as </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> years . </s>: Smoothed=0.002475, Unsmoothed=0.000000
# <s> yet about </s>: Smoothed=0.002475, Unsmoothed=0.000000

# %% [markdown]
# ### Generating Text
# In this example, we generate text using the **bigrams** model by providing a starting **prompt** (e.g., "the jury"). The `generate_text` function creates a sequence of words based on the trained bigram model, starting from the provided prompt and continuing based on the probabilities of the next words.
#
# After tokenizing the corpus, generating bigrams, and calculating their frequencies and probabilities, the model uses these learned probabilities to generate text. The generated output is then written to a file.
#
# Text generation with n-grams helps illustrate how language models can predict word sequences, allowing us to create new sentences that follow similar patterns found in the original text.

# %%
def generate_text(model: NGramModel, n: int, prompt: str) -> str:
    # create list of tokens incluing prompt tokens
    gen_tokens = []
    
    # generate tokens 
    for i in range(n):

        # fetch current token
        current_token = gen_tokens[-1] if len(gen_tokens) != 0 else prompt.split(" ")[-1]
        # get ngrams for last token
        token_ngram = model.ngrams[current_token]
        # next token mask
        next_token = (None, 0) # (token, prob)

        # loop over ngrams and select the one with highest probability
        for ngram in token_ngram:
            # print(f"ngram: {ngram}, prob.: {model.probabilities[ngram]}")
            # update token based on prob 
            if model.probabilities[ngram] > next_token[1]:
                next_token = (ngram.split(" ")[-2], model.probabilities[ngram])
        
        # append most probable word to generated tokens list
        gen_tokens.append(next_token[0])


    return ' '.join(gen_tokens)


tokens = model.tokenize()
ngrams = model.generate_ngrams(tokens)
model.count_frequencies()
model.calculate_probabilities()
generated_text = generate_text(model, 2, 'the jury')
with open(f'./results/generated_bigrams.txt', 'w') as file_:
    file_.write(generated_text)

# %% [markdown]
# ## Word Vectors
# Based on the Stanford course: https://web.stanford.edu/class/cs224n/

# %% [markdown]
# ### Count based W2V
# In this section, we use the previously trained **n-gram model** to calculate a **co-occurrence matrix**. A co-occurrence matrix shows how often words appear together within a specific context (in this case, bigrams), providing insights into word relationships in the corpus.
#
# Steps:
# 1. **Tokenization and N-gram Generation**: We first tokenize the text and generate bigrams using the `NGramModel`.
# 2. **Vocabulary and Indexing**: The vocabulary is created from the unique tokens, and a word-to-index mapping is established.
# 3. **Co-occurrence Matrix**: Using the generated n-grams, we compute the co-occurrence matrix, where each entry represents how often two words occur together within the bigrams.
#
# The co-occurrence matrix provides a numerical representation of word relationships, which is useful for tasks like word embeddings, semantic analysis, and understanding word associations.

# %%
# Since we already have a working ngram model, for the next part we can use the ngrams to calculate the co-occurences.
model = NGramModel(corpus, 2)
tokens = model.tokenize()
ngrams = model.generate_ngrams(tokens)

def create_co_matrix(ngrams: dict, vocab_size: int, word_to_index: dict) -> np.ndarray:
    # create co_matrix
    co_matrix = np.zeros((vocab_size, vocab_size))

    # remove faulty tokens 
    keys_to_remove = ["<", ">", "/", "s"]
    for key in keys_to_remove:
        ngrams.pop(key, None)

    # flatten ngrams
    flat_grams = [re.sub(r"</?s>", "", v).strip() for value in ngrams.values() for v in value]
    
    for ng in flat_grams:
        
        #  extract words from bigram
        first, second =  ng.split(" ")
        # get indices for words
        idx_f, idx_s = word_to_index[first], word_to_index[second]
        # print(f"Fist: {first}, idx: {idx_f}")

        # update co_matrix 
        co_matrix[idx_f][idx_s] += 1 
        co_matrix[idx_s][idx_f] += 1

    return co_matrix

vocab = list(set(tokens))
vocab_size = len(vocab)

# Create a word-to-index mapping
word_to_index = {word: idx for idx, word in enumerate(vocab)}

# Generate the co-occurrence matrix
co_matrix = create_co_matrix(ngrams, vocab_size, word_to_index)

# Optionally, print the matrix or parts of it
# print(pd.DataFrame(co_matrix).value_counts)

# for idx1, vect in enumerate(co_matrix):
#     for idx2, cell in enumerate(vect):
#         if cell != 0.0:
#             print(f"({idx1},{idx2})")

# %% [markdown]
# With the code below you can verify if the co-occurence works

# %%
def check_co_occurrence(word1, word2, co_matrix, word_to_index):
    """
    Print the co-occurrence count for a specific word pair.
    """
    if word1 not in word_to_index or word2 not in word_to_index:
        print(f"One or both words '{word1}' and '{word2}' are not in the vocabulary.")
        return

    index1 = word_to_index[word1]
    index2 = word_to_index[word2]

    co_count = co_matrix[index1][index2]
    print(f"Co-occurrence count for '{word1}' and '{word2}': {co_count}")

check_co_occurrence('the', 'jury', co_matrix, word_to_index)
check_co_occurrence('the', 'cat', co_matrix, word_to_index)
# Out:
# Co-occurrence count for 'the' and 'jury': 13.0
# One or both words 'the' and 'cat' are not in the vocabulary.

# %% [markdown]
# In this part, we reduce the dimensionality of the **co-occurrence matrix** using **Singular Value Decomposition (SVD)**. This technique helps in extracting the most important features from the matrix, making it easier to visualize and interpret the relationships between words.
#
# Steps:
# 1. **Singular Value Decomposition (SVD)**: The co-occurrence matrix is decomposed into three matrices: \( M = U \cdot \Sigma \cdot V^T \).
# 2. **Dimensionality Reduction**: We retain only the top `k` components (default is 2) from the SVD, effectively reducing the dimensionality of the matrix.
# 3. **Reduced Matrix**: The reduced matrix retains the most important semantic information and can be used for tasks such as **word embedding visualization** or **semantic similarity analysis**.
#
# Dimensionality reduction allows us to capture the essence of word relationships in fewer dimensions, making it more efficient to process and visualize the data.

# %%
def reduce_to_k_dim(M, k=2):
    # do singualr value decomposition
    U, Z, Vt = np.linalg.svd(M)

    # dimensionality reduction
    U_k = U[:, : k]
    Z_k = np.diag(Z[:k])
    Vt_k = Vt[: k, :]

    # matrix reconstruction
    M_reduced = U_k @  Z_k @ Vt_k

    return M_reduced

# %% [markdown]
# In this final part, we visualize the reduced word embeddings in **2D space**. After reducing the dimensionality of the co-occurrence matrix using SVD, we plot the embeddings for each word to observe their relationships in a low-dimensional space.
#
# Steps:
# 1. **Plotting the Embeddings**: Each word from the vocabulary is plotted based on its 2D coordinates from the reduced matrix.
# 2. **Visualization**: The scatter plot allows us to see how words cluster together or relate to each other based on co-occurrences in the text. Words with similar contexts should appear closer to each other in the plot.
# 3. **Interpretation**: By looking at the 2D plot, we can analyze word similarities, relationships, and clusters formed by words that often occur together.
#
# This visualization is a useful tool for understanding the structure of word embeddings and the relationships between words in the corpus.

# %%
def plot_embeddings(M_reduced, vocab):
    plt.figure(figsize=(10, 10))
    plt.scatter(M_reduced[:, 0], M_reduced[:, 1])
    for i, word in enumerate(vocab):
        plt.annotate(word, xy=(M_reduced[i, 0], M_reduced[i, 1]), fontsize=8)
    plt.title('Word Embeddings')
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.grid()
    os.makedirs('./results', exist_ok=True)
    plt.savefig('./results/word_embeddings.png')
    plt.show()

words = ['movie', 'book', 'mysterious', 'story', 'fascinating', 'good', 'interesting', 'large', 'massive', 'huge']
vocab = words
M = np.random.rand(len(words), 100)  # Dummy example for a 100D embedding
M_reduced = reduce_to_k_dim(M)
plot_embeddings(M_reduced, vocab)

# %% [markdown]
# ## Prediction-Based Word Vectors
# In this section, we load pre-trained word vectors using the **GloVe** embeddings from the [Stanford NLP paper on GloVe](https://nlp.stanford.edu/pubs/glove.pdf). The pre-trained embeddings provide rich semantic information about words based on large text corpora, allowing us to represent words as vectors that capture their meaning and relationships.
#
# Steps:
# 1. **Load GloVe Word Vectors**: We use the GloVe embeddings from the `glove-wiki-gigaword-200` model, which has 200-dimensional vectors for each word.
# 2. **Vocabulary Matching**: We map the words from our corpus to the GloVe vocabulary and extract the corresponding vectors.
# 3. **Dimensionality Reduction**: After obtaining the word vectors, we reduce the dimensionality to visualize the embeddings in 2D space, allowing us to explore word relationships visually.
#
# This is an excellent opportunity to explore how pre-trained embeddings like GloVe can be used to improve downstream NLP tasks by providing richer word representations.

# %%
# Do not edit
import gensim.downloader as api
import numpy as np
wv_from_bin = api.load("glove-wiki-gigaword-200")
print("Loaded vocab size %i" % len(list(wv_from_bin.index_to_key)))

wv_words = list(wv_from_bin.index_to_key)
unique_tokens = set(tokens)
word2ind = {}
M = []
idx = 0
print('rendering M based on wv')
for w in wv_words:
    try:
        M.append(wv_from_bin.get_vector(w))
        word2ind[w] = idx
        idx += 1
    except:
        pass

print('rendering M based on unique_tokens')
for w in unique_tokens:
    if w in wv_words:
        continue
    try:
        M.append(wv_from_bin.get_vector(w))
        word2ind[w] = idx
        idx += 1
    except:
        pass
M = np.stack(M)
M_reduced = reduce_to_k_dim(M, k=2)

M_lengths = np.linalg.norm(M_reduced, axis=1)
M_reduced_normalized = M_reduced / M_lengths[:, np.newaxis]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 4
#       1 # Do not edit
#       2 # import gensim.downloader as api
#       3 import numpy as np
# ----> 4 wv_from_bin = api.load("glove-wiki-gigaword-200")
#       5 print("Loaded vocab size %i" % len(list(wv_from_bin.index_to_key)))
#       7 wv_words = list(wv_from_bin.index_to_key)
#
# NameError: name 'api' is not defined

# %% [markdown]
# ### Compare plots
# What stands out when comparing the two different ways of embedding using the given words?
#
# (Use this to help answer the question in your assignment document).

# %%
M_reduced = reduce_to_k_dim(M, k=2)

# Normalize the reduced embeddings
M_lengths = np.linalg.norm(M_reduced, axis=1, keepdims=True)
M_reduced_normalized = M_reduced / M_lengths

# Make sure the number of tokens matches the number of vectors
tokens_trimmed = tokens[:M_reduced_normalized.shape[0]]

plot_embeddings(M_reduced_normalized, tokens_trimmed)

# %% [markdown]
# ### Words with multiple meanings
# Polysemes and homonyms are words that have more than one meaning (see [this wiki page](https://en.wikipedia.org/wiki/Polysemy) to learn more about the difference between polysemes and homonyms). Your task is to find a word with at least two different meanings such that the top-10 most similar words (according to cosine similarity) contain related words from both meanings.
#
# For example:
# - "leaves" has both the "go_away" and "a_structure_of_a_plant" meanings in the top 10.
# - "scoop" has both "handed_waffle_cone" and "lowdown" meanings in the top 10.
#
# You will probably need to try several polysemous or homonymic words before you find one.
#
# Once you discover a word that fits this criterion, state the word and explain the multiple meanings that occur in the top 10. Reflect on why many of the polysemous or homonymic words you tried didn’t work (i.e., why the top-10 most similar words only contain one of the word's meanings).
#
# **Note**: Use the `wv_from_bin.most_similar(word)` function to get the top 10 most similar words. This function ranks all other words in the vocabulary based on their cosine similarity to the given word. For further assistance, you can refer to the [Gensim documentation](https://radimrehurek.com/gensim/models/keyedvectors.html).

# %%
## Your code here
word = "draft"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            
top_10_most_similar = wv_from_bin.most_similar(word)
print(top_10_most_similar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 3
#       1 ## Your code here
#       2 word = "draft"
# ----> 3 top_10_most_similar = wv_from_bin.most_similar(word)
#       4 print(top_10_most_similar)
#
# NameError: name 'wv_from_bin' is not defined

# %% [markdown]
# #### Answer:
# A word that we could identify that has several different meanings is draft, which can be used in the context of either drafting a document, drafting a beer or drafting a player in a sport. The top 10 most similar words identified by our function included both words from the world of sports as also words related to the context of drafting a proposal. For example, "proposal", "document" and "signed" are related to the meaning of the word in the context of drafting a document, whereas "pick", "nfl" and "signed" is related to the meaning of the word in the world of sports.
#
# Before trying "draft" we tried to find such a case with a wide range of words with several meanings such as "bat","bank" and "match", which we did not choose because they only contained words from one of the meanings. This is due to the fact that the word embedding and thus the cosine similarity is based on the contexts of the words. If contexts related to one domain dominated other contexts or if other contexts, which semantically exist, did not occur it would not encode that meaning effectively and would thus have a low cosine similarity.

# %% [markdown]
# ### Synonyms
# When considering **Cosine Similarity**, it's often useful to think of **Cosine Distance**, which is simply 1 - Cosine Similarity.
#
# Find three words \( (w_1, w_2, w_3) \) where:
# - \(w_1\) and \(w_2\) are **synonyms**.
# - \(w_1\) and \(w_3\) are **antonyms**.
#
# However, you need to find a case where **Cosine Distance** \( (w_1, w_3) < \text{Cosine Distance} (w_1, w_2) \). In other words, the antonym is **closer** to the word than its synonym in the vector space.
#
# For example, "happy" (\(w_1\)) may be closer to "sad" (\(w_3\)) than to "cheerful" (\(w_2\)), which is counter-intuitive since we expect synonyms to be closer than antonyms.
#
# Once you find such an example, provide a possible explanation for why this result may have occurred.
#
# Use the `wv_from_bin.distance(w1, w2)` function to compute the cosine distance between two words. You can refer to the [Gensim documentation](https://radimrehurek.com/gensim/models/keyedvectors.html) for further assistance.

# %%
## Your code here
words = [["smart","clever","dumb"],["strong","mighty","weak"],["real","true","fake"],
         ["active","lively","passive"],["love","affection","hate"],["sadness","sorrow","happiness"],
         ["artificial","synthetic","natural"],["crazy","mad","sane"],["shy","timid","outgoing"]]

def find_weird_case(words):
    cos_w1_w3 = wv_from_bin.distance(words[0],words[2])
    cos_w1_w2 = wv_from_bin.distance(words[0],words[1])
    if cos_w1_w3<cos_w1_w2:
        return True
    else:
        return False
flag =False    
for word_set in words:
    if find_weird_case(word_set):
        print(f"We found a case! It is {word_set}")
        flag = True
if flag == False:
    print("There was no case yet found we have to try more")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 15
#      13 flag =False
#      14 for word_set in words:
# ---> 15     if find_weird_case(word_set):
#      16         print(f"We found a case! It is {word_set}")
#      17         flag = True
#
# Cell In[82], line 7, in find_weird_case(words)
#       6 def find_weird_case(words):
# ----> 7     cos_w1_w3 = wv_from_bin.distance(words[0],words[2])
#       8     cos_w1_w2 = wv_from_bin.distance(words[0],words[1])
#       9     if cos_w1_w3<cos_w1_w2:
#
# NameError: name 'wv_from_bin' is not defined

# %% [markdown]
# #### Answer:
# We found three cases where the cosine distance of the word to its antonym was smaller than to its synonym. One such case was "strong", which had a lower cosine distance to "weak" than to "mighty". This could be due to the fact that "strong" and "weak" occur in similar contexts, such as "the man had a strong argument" vs "the man had a weak argument" whereas "the man had a mighty argument" would be odd. Furthermore, synonyms with a low frequency in the corpus could have a biased cosine distance. This reflects the fact that the embeddings of words is based on contextual similarity but not actually semantic similarity, although the two conepts might be closely related in practice.

# %% [markdown]
# ### Analogies
# Word vectors have demonstrated the ability to solve analogies based on their learned semantic relationships. For instance, consider the analogy:
#
# **"man : grandfather :: woman : x"**
#
# (Read: man is to grandfather as woman is to x). Using word vectors, we can find the word \(x\) that completes the analogy.
#
# In the example provided, we use the `most_similar` function from the Gensim library. This function identifies words that are most similar to the words in the positive list and most dissimilar to those in the negative list. For analogy solving, it effectively computes:
#
# \[ \text{word}(x) = \text{most similar to} (\text{woman} + \text{grandfather} - \text{man}) \]
#
# The result is the word with the highest cosine similarity to the target vector. You can use this approach to explore various analogies and gain insights into the semantic structure of word vectors.
#
# Refer to the [Gensim documentation](https://radimrehurek.com/gensim/models/keyedvectors.html) for more details on the `most_similar` function and how word vectors handle analogy-solving tasks.

# %%
# Run this cell to answer the analogy -- man : grandfather :: woman : x
print(wv_from_bin.most_similar(positive=['woman', 'grandfather'], negative=['man']))
# Out:
# [('grandmother', 0.7608445286750793), ('granddaughter', 0.7200808525085449), ('daughter', 0.7168302536010742), ('mother', 0.7151536345481873), ('niece', 0.7005682587623596), ('father', 0.6659887433052063), ('aunt', 0.6623408794403076), ('grandson', 0.6618767976760864), ('grandparents', 0.6446609497070312), ('wife', 0.644535481929779)]

# %% [markdown]
# ### Bias in word vectors
# a. **Observation**: Consider the results of a word vector model when queried with analogies involving "man", "woman", and "profession". What are the top results returned by the model for each query?
#
# [Your Answer]
#
# b. **Analysis**: Do you observe any gender biases in the results? For example, are certain professions more closely associated with "man" or "woman" based on the word vectors? Discuss how word embeddings might perpetuate societal biases present in the training data.
#
# [Your Answer]
#
# c. **Reflection**: How might such biases affect the fairness of machine learning models that use word embeddings? Suggest potential strategies for mitigating gender bias in word vector models.
#
# [Your Answer]

# %%
print(wv_from_bin.most_similar(positive=['man', 'profession'], negative=['woman']))
print()
print(wv_from_bin.most_similar(positive=['woman', 'profession'], negative=['man']))
# Out:
# [('reputation', 0.5250176787376404), ('professions', 0.5178037881851196), ('skill', 0.49046966433525085), ('skills', 0.49005505442619324), ('ethic', 0.4897659420967102), ('business', 0.487585186958313), ('respected', 0.485920250415802), ('practice', 0.4821045696735382), ('regarded', 0.4778572618961334), ('life', 0.4760662019252777)]
#
# [('professions', 0.5957458019256592), ('practitioner', 0.4988412857055664), ('teaching', 0.48292139172554016), ('nursing', 0.48211804032325745), ('vocation', 0.4788965880870819), ('teacher', 0.47160351276397705), ('practicing', 0.4693780839443207), ('educator', 0.46524327993392944), ('physicians', 0.4628995656967163), ('professionals', 0.46013936400413513)]
